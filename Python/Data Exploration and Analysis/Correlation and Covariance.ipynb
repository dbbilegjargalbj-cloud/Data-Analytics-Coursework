# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
MSRP = pd.read_csv(r'/Users/bilegjargalbattulga/Desktop/data analyst/Python for Dana Analysis/Data Exploration and Analysis/car_sales.csv')

# %%
MSRP.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
MSRP.corr()
# Out:
# /var/folders/mm/dk0qprd53tb6f0y8g20c97vr0000gn/T/ipykernel_69658/3333037176.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   MSRP.corr()
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
# ...

# %%
corr_msrp = MSRP.corr()
# Out:
# /var/folders/mm/dk0qprd53tb6f0y8g20c97vr0000gn/T/ipykernel_69658/3243891124.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_msrp = MSRP.corr()

# %%
sns.heatmap(corr_msrp, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
MSRP.corr(method = "spearman") # for raw data spearman is better
# Out:
# /var/folders/mm/dk0qprd53tb6f0y8g20c97vr0000gn/T/ipykernel_69658/3086532006.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   MSRP.corr(method = "spearman") # for raw data spearman is better
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.330883         -0.089457         0.241693
# Engine HP         0.330883   1.000000          0.749650        -0.014737
# Engine Cylinders -0.089457   0.749650          1.000000        -0.105626
# Number of Doors   0.241693  -0.014737         -0.105626         1.000000
# highway MPG       0.332119  -0.492900         -0.765168         0.137166
# city mpg          0.301150  -0.583996         -0.837934         0.158429
# Popularity        0.185043   0.030181          0.022236        -0.060008
# ...

# %%
MSRP.corr(method = "kendall") # too strict
# Out:
# /var/folders/mm/dk0qprd53tb6f0y8g20c97vr0000gn/T/ipykernel_69658/765659908.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   MSRP.corr(method = "kendall") # too strict
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.237415         -0.070319         0.203430
# Engine HP         0.237415   1.000000          0.620364        -0.010974
# Engine Cylinders -0.070319   0.620364          1.000000        -0.098048
# Number of Doors   0.203430  -0.010974         -0.098048         1.000000
# highway MPG       0.237267  -0.350132         -0.638312         0.112684
# city mpg          0.215461  -0.425528         -0.721069         0.131542
# Popularity        0.133486   0.020071          0.017419        -0.048963
# ...

# %%
MSRP.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
sns.scatterplot(data = MSRP, x = 'Engine HP', y = 'MSRP')

sns.regplot(data = MSRP, x = 'Engine HP', y = 'MSRP', scatter = False, color = 'red')

plt.show()

# %%
sns.scatterplot(data = MSRP, x = 'Engine Cylinders', y = 'city mpg')

sns.regplot(data = MSRP, x = 'Engine Cylinders', y = 'city mpg', scatter = False, color = 'red')

plt.show()

# %% [markdown]
# ###  Covariance

# %% [raw]
# looks at the relationship whether its negative or positive
# not standardized like correlation
# so correlation is just standardized covariance

# %%
MSRP.cov()
# Out:
# /var/folders/mm/dk0qprd53tb6f0y8g20c97vr0000gn/T/ipykernel_69658/1720991164.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   MSRP.cov()
#                            Year     Engine HP  Engine Cylinders  \
# Year                  57.452457  2.915880e+02         -0.560066
# Engine HP            291.588019  1.192286e+04        149.338158
# Engine Cylinders      -0.560066  1.493382e+02          3.170392
# Number of Doors        1.762368 -9.892033e+00         -0.219406
# highway MPG           17.348355 -3.429488e+02         -9.516859
# city mpg              13.500413 -3.408537e+02         -9.084998
# Popularity           798.346061  5.891934e+03        105.713515
# MSRP              103692.370363  4.355284e+06      56932.619101
#
#                   Number of Doors   highway MPG      city mpg    Popularity  \
# ...
