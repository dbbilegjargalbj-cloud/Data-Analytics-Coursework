# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/bilegjargalbattulga/Desktop/data analyst/Python for Dana Analysis/Filtering and Ordering/laptop_prices.csv'
                , encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 1350)
pd.set_option('display.max.columns', 15)

# %%
df[df['Product'] == 'Blade Pro'].sort_values(by = 'Price_usd', ascending = False)
# Out:
#       laptop_ID Company    Product TypeName  Inches  \
# 196         200   Razer  Blade Pro   Gaming    17.3
# 830         839   Razer  Blade Pro   Gaming    17.3
# 1231       1249   Razer  Blade Pro   Gaming    14.0
# 778         787   Razer  Blade Pro   Gaming    14.0
# 647         655   Razer  Blade Pro   Gaming    14.0
#
#                          ScreenResolution                          Cpu   Ram  \
# 196   4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
# 830   4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
# 1231                    Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 778                     Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 647                     Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
#
#          Memory                      Gpu       OpSys  Weight  Price_usd
# 196     1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg     6708.9
# ...

# %%
df[df['Company'] == 'Razer'].sort_values(by = ['Inches', 'Price_usd'], ascending = [True, False])
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 816         825   Razer  Blade Stealth  Ultrabook    12.5
# 1117       1132   Razer  Blade Stealth  Ultrabook    12.5
# 1231       1249   Razer      Blade Pro     Gaming    14.0
# 778         787   Razer      Blade Pro     Gaming    14.0
# 647         655   Razer      Blade Pro     Gaming    14.0
# 196         200   Razer      Blade Pro     Gaming    17.3
# 830         839   Razer      Blade Pro     Gaming    17.3
#
#                                    ScreenResolution  \
# 816   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 1117            Touchscreen / 4K Ultra HD 3840x2160
# 1231                              Full HD 1920x1080
# 778                               Full HD 1920x1080
# 647                               Full HD 1920x1080
# 196             4K Ultra HD / Touchscreen 3840x2160
# 830             4K Ultra HD / Touchscreen 3840x2160
#
# ...
