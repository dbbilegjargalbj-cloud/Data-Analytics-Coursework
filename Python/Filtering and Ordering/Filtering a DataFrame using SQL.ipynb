# %%
# !NOT EXACTLY SQL,
# actually a PANDAS QUERY LANGUAGE,
# but based off of SQL.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/bilegjargalbattulga/Desktop/data analyst/Python for Dana Analysis/Filtering and Ordering/laptop_prices.csv'
                , encoding = 'ISO-8859-1')
pd.set_option('display.max.rows', 1350)
pd.set_option('display.max.columns', 15)

# %%
df.query('Price_usd > 1200')
# Out:
#       laptop_ID    Company                                     Product  \
# 0             1      Apple                                 MacBook Pro
# 3             4      Apple                                 MacBook Pro
# 4             5      Apple                                 MacBook Pro
# 6             7      Apple                                 MacBook Pro
# 7             8      Apple                                 Macbook Air
# 8             9       Asus                             ZenBook UX430UN
# 12           13      Apple                                 MacBook Pro
# 14           15      Apple                                 MacBook 12"
# 15           16      Apple                                 MacBook Pro
# 17           18      Apple                                 MacBook Pro
# 26           27      Apple                                 MacBook Air
# 28           29       Dell                               Latitude 5590
# ...

# %%
df.query("Company == 'Apple' or Company == 'Dell'")
# Out:
#       laptop_ID Company          Product            TypeName  Inches  \
# 0             1   Apple      MacBook Pro           Ultrabook    13.3
# 1             2   Apple      Macbook Air           Ultrabook    13.3
# 3             4   Apple      MacBook Pro           Ultrabook    15.4
# 4             5   Apple      MacBook Pro           Ultrabook    13.3
# 6             7   Apple      MacBook Pro           Ultrabook    15.4
# 7             8   Apple      Macbook Air           Ultrabook    13.3
# 12           13   Apple      MacBook Pro           Ultrabook    15.4
# 13           14    Dell    Inspiron 3567            Notebook    15.6
# 14           15   Apple      MacBook 12"           Ultrabook    12.0
# 15           16   Apple      MacBook Pro           Ultrabook    13.3
# 16           17    Dell    Inspiron 3567            Notebook    15.6
# 17           18   Apple      MacBook Pro           Ultrabook    15.4
# 19           20    Dell           XPS 13           Ultrabook    13.3
# ...

# %%
df.query("Company == 'Apple' and Price_usd > 1500")
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 4            5   Apple  MacBook Pro  Ultrabook    13.3
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 15          16   Apple  MacBook Pro  Ultrabook    13.3
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 45          46   Apple  MacBook Pro  Ultrabook    13.3
# 81          83   Apple  MacBook 12"  Ultrabook    12.0
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
# 270        275   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 4    IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# ...

# %%
# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=6622d854f31d0d02f83ad6cec68bd4e5cbd4c2861713c7e8c88a8b6ef4ea49ba
#   Stored in directory: /Users/bilegjargalbattulga/Library/Caches/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# ...

# %%
import pandasql as psql

# %%
psql.sqldf("SELECT * FROM df WHERE Company = 'Apple'")
# Out:
#     laptop_ID Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           4   Apple  MacBook Pro  Ultrabook    15.4
# 3           5   Apple  MacBook Pro  Ultrabook    13.3
# 4           7   Apple  MacBook Pro  Ultrabook    15.4
# 5           8   Apple  Macbook Air  Ultrabook    13.3
# 6          13   Apple  MacBook Pro  Ultrabook    15.4
# 7          15   Apple  MacBook 12"  Ultrabook    12.0
# 8          16   Apple  MacBook Pro  Ultrabook    13.3
# 9          18   Apple  MacBook Pro  Ultrabook    15.4
# 10         27   Apple  MacBook Air  Ultrabook    13.3
# 11         35   Apple  MacBook Air  Ultrabook    13.3
# 12         46   Apple  MacBook Pro  Ultrabook    13.3
# 13         83   Apple  MacBook 12"  Ultrabook    12.0
# 14        254   Apple  MacBook Pro  Ultrabook    13.3
# 15        275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
psql.sqldf("SELECT * FROM df WHERE Company = 'Apple' and 'Inches' > 14")
# Out:
#     laptop_ID Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           4   Apple  MacBook Pro  Ultrabook    15.4
# 3           5   Apple  MacBook Pro  Ultrabook    13.3
# 4           7   Apple  MacBook Pro  Ultrabook    15.4
# 5           8   Apple  Macbook Air  Ultrabook    13.3
# 6          13   Apple  MacBook Pro  Ultrabook    15.4
# 7          15   Apple  MacBook 12"  Ultrabook    12.0
# 8          16   Apple  MacBook Pro  Ultrabook    13.3
# 9          18   Apple  MacBook Pro  Ultrabook    15.4
# 10         27   Apple  MacBook Air  Ultrabook    13.3
# 11         35   Apple  MacBook Air  Ultrabook    13.3
# 12         46   Apple  MacBook Pro  Ultrabook    13.3
# 13         83   Apple  MacBook 12"  Ultrabook    12.0
# 14        254   Apple  MacBook Pro  Ultrabook    13.3
# 15        275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
psql.sqldf("SELECT Company, Product FROM df WHERE Product LIKE '%MacBook%'")
# Out:
#    Company      Product
# 0    Apple  MacBook Pro
# 1    Apple  Macbook Air
# 2    Apple  MacBook Pro
# 3    Apple  MacBook Pro
# 4    Apple  MacBook Pro
# 5    Apple  Macbook Air
# 6    Apple  MacBook Pro
# 7    Apple  MacBook 12"
# 8    Apple  MacBook Pro
# 9    Apple  MacBook Pro
# 10   Apple  MacBook Air
# 11   Apple  MacBook Air
# 12   Apple  MacBook Pro
# 13   Apple  MacBook 12"
# 14   Apple  MacBook Pro
# 15   Apple  MacBook Pro
# 16   Apple  MacBook 12"
# 17   Apple  MacBook 12"
# 18   Apple  MacBook 12"
# 19   Apple  MacBook 12"
# 20   Apple  MacBook Air

# %%
psql.sqldf("SELECT * FROM df ORDER BY Price_usd ASC ")
# Out:
#       laptop_ID    Company                                        Product  \
# 0          1233       Acer               C740-C9QX (3205U/2GB/32GB/Chrome
# 1            21       Asus                                Vivobook E200HA
# 2          1135       Vero               V131 (X5-Z8350/4GB/32GB/FHD/W10)
# 3            32       Asus           E402WA-GA010T (E2-6110/2GB/32GB/W10)
# 4           295       Acer                           Chromebook C910-C2ST
# 5           800       Vero                      K146 (N3350/4GB/32GB/W10)
# 6          1117       Acer                                  Chromebook 15
# 7          1286         HP                               Stream 11-Y000na
# 8          1300         HP                               Stream 11-Y000na
# 9          1314         HP                               Stream 11-Y000na
# 10         1055       Vero                   V142 (X5-Z8350/2GB/32GB/W10)
# 11          562       Asus           A541NA-GO342 (N3350/4GB/500GB/Linux)
# ...
